# %% [markdown]
# # Генератор пользовательских данных для детектирования клеток крови — HT_5
#
# 1.	Преобразуйте генератор данных для решения задачи детектирования объекта (таргет сформирован в виде x,y,w,h).
# 2.	Выберите модель YOLO из представленных. Натренируйте модель для решения задачи детектирования клеток Model Training with Ultralytics YOLO - Ultralytics YOLO Docs. bing.com/ck/a?!&&p=b3441c4eae8ebdb939a51092e90a86948b3b4c219a460d43461448e588b9e8a0JmltdHM9MTc3NzA3NTIwMA&ptn=3&ver=2&hsh=4&fclid=12094f40-6510-69b3-1238-5a946447681d&psq=yolo+detection+training&u=a1aHR0cHM6Ly9kb2NzLnVsdHJhbHl0aWNzLmNvbS90YXNrcy9kZXRlY3Qv&ntb=1
# 3.	Решите хадачу подсчета количества клеток. Количество найденных клеток является корректным, если относительная погрешность вычислений меньше 10%.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
import random
from typing import Tuple, List
from torch.utils.data import Dataset
from torch.utils.data import random_split
import torch
from torchvision import transforms
from tqdm import tqdm
from ultralytics import YOLO

# %% [markdown]
# ## 1. Загрузка и подготовка данных

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

MAX_CELLS = 9
BATCH_SIZE = 16
EPOCHS = 50
LR = 0.001

TOTAL_DATA = 1000
TRAIN_RATIO = 0.8
VAL_RATIO = 0.2

TRAIN_SIZE = int(TOTAL_DATA * TRAIN_RATIO)
VAL_SIZE = int(TOTAL_DATA * VAL_RATIO)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")

DATA_DIR = 'BCCD Dataset with mask/train'
IMAGES_DIR = os.path.join(DATA_DIR, 'original')
MASKS_DIR = os.path.join(DATA_DIR, 'mask')

BACKGROUND_PATCHES_DIR = 'background_patches'
CELL_PATCHES_DIR = 'cell_patches'
os.makedirs(BACKGROUND_PATCHES_DIR, exist_ok=True)
os.makedirs(CELL_PATCHES_DIR, exist_ok=True)

YOLO_DATASET_DIR = "yolo_cell_dataset"
for split in ['train', 'val']:
    os.makedirs(os.path.join(YOLO_DATASET_DIR, split, 'images'), exist_ok=True)
    os.makedirs(os.path.join(YOLO_DATASET_DIR, split, 'labels'), exist_ok=True)
# Out:
# Device: cuda

# %%
def load_blood_cell_dataset(images_dir, masks_dir, max_images=1000):
    images = []
    masks = []
    
    for filename in os.listdir(images_dir):
        if len(images) >= max_images:
            break
            
        img_path = os.path.join(images_dir, filename)
        mask_path = os.path.join(masks_dir, filename)
        
        if os.path.exists(mask_path):
            img = cv2.imread(img_path)
            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
            
            if img is not None and mask is not None:
                images.append(img)
                masks.append(mask)
    
    return images, masks

# %%
def extract_patches(images, masks, patch_size=(128, 128), n_patches=100):
    background_patches = []
    cell_patches = []
    
    for img, mask in zip(images, masks):
        h, w = img.shape[:2]
        
        for _ in range(n_patches // 2):
            x = random.randint(0, w - patch_size[1])
            y = random.randint(0, h - patch_size[0])
            
            patch = img[y:y+patch_size[0], x:x+patch_size[1]]
            mask_patch = mask[y:y+patch_size[0], x:x+patch_size[1]]
            
            if np.count_nonzero(mask_patch) < patch_size[0] * patch_size[1] * 0.05:
                background_patches.append(patch)
        
        contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        for contour in contours:
            x, y, w_cell, h_cell = cv2.boundingRect(contour)
            
            if w_cell > 20 and h_cell > 20:
                pad = 10
                x1 = max(0, x - pad)
                y1 = max(0, y - pad)
                x2 = min(img.shape[1], x + w_cell + pad)
                y2 = min(img.shape[0], y + h_cell + pad)
                
                cell_patch = img[y1:y2, x1:x2]
                cell_mask = mask[y1:y2, x1:x2]
                
                cell_only = cv2.bitwise_and(cell_patch, cell_patch, mask=cell_mask)
                if cell_only.size > 0:
                    cell_patches.append(cell_only)
    
    return background_patches, cell_patches

# %%
def save_patches(background_patches, cell_patches, bg_dir, cell_dir, max_save=50):
    for i, patch in enumerate(background_patches[:max_save]):
        cv2.imwrite(os.path.join(bg_dir, f'bg_{i}.png'), patch)
    
    for i, patch in enumerate(cell_patches[:max_save]):
        cv2.imwrite(os.path.join(cell_dir, f'cell_{i}.png'), patch)
    
    print(f"Сохранено {len(background_patches)} патчей фона и {len(cell_patches)} патчей клеток")

# %%
try:
    images, masks = load_blood_cell_dataset(IMAGES_DIR, MASKS_DIR, 200)
    print(f"Загружено {len(images)} изображений")
    
    bg_patches, cell_patches = extract_patches(images, masks)
    save_patches(bg_patches, cell_patches, BACKGROUND_PATCHES_DIR, CELL_PATCHES_DIR)
    
except FileNotFoundError:
    print("Набор данных не найден. Используем синтетические данные.")
    bg_patches, cell_patches = [], []
# Out:
# Загружено 200 изображений
# Сохранено 2265 патчей фона и 14454 патчей клеток

# %%
fig, axes = plt.subplots(5, 2, figsize=(12, 25))
fig.suptitle("Примеры загруженных данных", fontsize=16)

for i in range(5):
    axes[i, 0].imshow(cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB))
    axes[i, 0].set_title(f"Исходное изображение {i+1}")
    axes[i, 0].axis('off')
    
    axes[i, 1].imshow(masks[i], cmap='gray')
    axes[i, 1].set_title(f"Маска сегментации {i+1}")
    axes[i, 1].axis('off')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
fig.suptitle("Примеры bg_patches", fontsize=16)

for i in range(10):
    row = i // 5
    col = i % 5
    axes[row, col].imshow(cv2.cvtColor(bg_patches[i], cv2.COLOR_BGR2RGB))
    axes[row, col].set_title(f"Patch {i+1}")
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Реализация Dataset класса

# %%
class CellDetectionDataset(Dataset):
    def __init__(
        self,
        img_size: Tuple[int, int] = (416, 416),
        dataset_size: int = 200,
        bg_patches: List = None,
        cell_patches: List = None,
        p_background_solid: float = 0.3,
        p_cell_artificial: float = 0.3,
        min_cells_count: int = 1,
        max_cells_count: int = 9,
        min_cell_coverage: float = 0.3,
        seed: int = 42
    ):
        random.seed(seed)
        np.random.seed(seed)
        
        self.img_size = img_size
        self.dataset_size = dataset_size
        self.bg_patches = bg_patches if bg_patches else []
        self.cell_patches = cell_patches if cell_patches else []
        self.p_background_solid = p_background_solid
        self.p_cell_artificial = p_cell_artificial
        self.min_cells_count = min_cells_count
        self.max_cells_count = max_cells_count
        self.min_cell_coverage = min_cell_coverage
        
        self.normalize = transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225])
    
    def __len__(self):
        return self.dataset_size
    
    def __getitem__(self, item):
        target_cells = random.randint(self.min_cells_count, self.max_cells_count)
        clean_img = self._select_background()
        
        cells_img = np.zeros((clean_img.shape[0], clean_img.shape[1], 3), dtype=np.uint8)
        cells_mask = np.zeros((clean_img.shape[0], clean_img.shape[1]), dtype=np.uint8)
        
        bboxes = []
        
        actual_cells_count = 0
        for _ in range(target_cells):
            for _max_attempts in range(2000):
                temp_mask = np.zeros_like(cells_mask)
                temp_img = np.zeros_like(cells_img)
                
                x = random.randint(0, clean_img.shape[1] - 10)
                y = random.randint(0, clean_img.shape[0] - 10)
                
                use_artificial_cell = random.random() < self.p_cell_artificial
                rad = random.randint(12, 25)
                color = self._get_cell_color()
                
                if use_artificial_cell and len(self.cell_patches) > 0:
                    patch = random.choice(self.cell_patches)
                    patch = cv2.resize(patch, (rad*2, rad*2))
                    h_patch, w_patch = patch.shape[:2]
                    x1 = max(0, min(x - w_patch//2, clean_img.shape[1] - w_patch))
                    y1 = max(0, min(y - h_patch//2, clean_img.shape[0] - h_patch))
                    temp_mask[y1:y1+h_patch, x1:x1+w_patch] = 255
                    temp_img[y1:y1+h_patch, x1:x1+w_patch] = patch

                    box_x = x1 + w_patch/2
                    box_y = y1 + h_patch/2
                    box_w = w_patch
                    box_h = h_patch
                elif len(self.cell_patches) > 0:
                    cell_patch = random.choice(self.cell_patches)
                    cell_patch = cv2.resize(cell_patch, (rad*2, rad*2))
                    h_patch, w_patch = cell_patch.shape[:2]
                    x1 = max(0, min(x - w_patch//2, clean_img.shape[1] - w_patch))
                    y1 = max(0, min(y - h_patch//2, clean_img.shape[0] - h_patch))
                    temp_mask[y1:y1+h_patch, x1:x1+w_patch] = 255
                    temp_img[y1:y1+h_patch, x1:x1+w_patch] = cell_patch
                    
                    box_x = x1 + w_patch/2
                    box_y = y1 + h_patch/2
                    box_w = w_patch
                    box_h = h_patch
                else:
                    cv2.circle(temp_mask, center=(x, y), radius=rad, color=255, thickness=-1)
                    cv2.circle(temp_img, center=(x, y), radius=rad, color=color, thickness=-1)
                    box_x = x
                    box_y = y
                    box_w = rad*2
                    box_h = rad*2

                temp_mask_without = cv2.bitwise_and(temp_mask, cv2.bitwise_not(cells_mask))
                coverage = np.count_nonzero(temp_mask_without) / max(1, np.count_nonzero(temp_mask))
                
                if coverage >= self.min_cell_coverage:
                    cells_img = self._add_image_with_mask(cells_img, temp_img, temp_mask_without)
                    cells_mask = self._add_image_with_mask(cells_mask, temp_mask, temp_mask_without)

                    norm_x = box_x / clean_img.shape[1]
                    norm_y = box_y / clean_img.shape[0]
                    norm_w = box_w / clean_img.shape[1]
                    norm_h = box_h / clean_img.shape[0]
                    bboxes.append([norm_x, norm_y, norm_w, norm_h])
                    
                    actual_cells_count += 1
                    break
        
        clean_img = self._add_image_with_mask(clean_img, cells_img, cells_mask)
        image = cv2.cvtColor(clean_img, cv2.COLOR_BGR2RGB)
        image = torch.tensor(image, dtype=torch.float32).permute(2, 0, 1) / 255.0
        image = self.normalize(image)

        return image, torch.tensor(bboxes, dtype=torch.float32), actual_cells_count
    
    def _select_background(self):
        if random.random() < self.p_background_solid or len(self.bg_patches) == 0:
            color = [random.randint(150, 220) for _ in range(3)]
            return np.ones((self.img_size[0], self.img_size[1], 3), dtype=np.uint8) * color
        else:
            bg = np.zeros((self.img_size[0], self.img_size[1], 3), dtype=np.uint8)
            patch_size = 128
            for i in range(0, self.img_size[0], patch_size):
                for j in range(0, self.img_size[1], patch_size):
                    if len(self.bg_patches) > 0:
                        patch = random.choice(self.bg_patches)
                        patch = cv2.resize(patch, (patch_size, patch_size))
                    else:
                        patch = np.ones((patch_size, patch_size, 3), dtype=np.uint8) * 220
                    h_end = min(i + patch_size, self.img_size[0])
                    w_end = min(j + patch_size, self.img_size[1])
                    bg[i:h_end, j:w_end] = patch[:h_end-i, :w_end-j]
            return bg
    
    def _get_cell_color(self):
        return (random.randint(150, 200), random.randint(100, 200), random.randint(50, 150))
    
    def _add_image_with_mask(self, a, b, mask):
        a = a.astype(np.uint8)
        b = b.astype(np.uint8)
        mask = mask.astype(np.uint8)
        result = a.copy()
        result[mask > 0] = b[mask > 0]
        return result

# %%
def convert_to_yolo_format(dataset, split_name, output_dir, img_size=(416,416)):
    out_img_dir = os.path.join(output_dir, split_name, 'images')
    out_label_dir = os.path.join(output_dir, split_name, 'labels')
    
    for idx in tqdm(range(len(dataset)), desc=f"Converting {split_name}"):
        img_tensor, bboxes, cell_count = dataset[idx]
        
        img_disp = img_tensor.clone()
        img_disp = img_disp * torch.tensor([0.229, 0.224, 0.225]).view(3,1,1) + torch.tensor([0.485, 0.456, 0.406]).view(3,1,1)
        img_disp = (img_disp.permute(1,2,0).numpy() * 255).astype(np.uint8)
        
        img_path = os.path.join(out_img_dir, f"{idx:05d}.png")
        cv2.imwrite(img_path, cv2.cvtColor(img_disp, cv2.COLOR_RGB2BGR))
        
        label_path = os.path.join(out_label_dir, f"{idx:05d}.txt")
        with open(label_path, 'w') as f:
            for box in bboxes:
                f.write(f"0 {box[0]:.6f} {box[1]:.6f} {box[2]:.6f} {box[3]:.6f}\n")

# %%
full_dataset = CellDetectionDataset(
    img_size=(416, 416),
    dataset_size=TOTAL_DATA,
    bg_patches=bg_patches,
    cell_patches=cell_patches,
    min_cells_count=1,
    max_cells_count=MAX_CELLS
)

train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

convert_to_yolo_format(train_dataset, 'train', YOLO_DATASET_DIR)
convert_to_yolo_format(val_dataset, 'val', YOLO_DATASET_DIR)

print(f"YOLO датасет создан в {YOLO_DATASET_DIR}")
print(f"Train: {len(train_dataset)} images, Val: {len(val_dataset)} images")
# Out:
# Converting train: 100%|██████████| 800/800 [00:13<00:00, 61.30it/s]
# Converting val: 100%|██████████| 200/200 [00:03<00:00, 61.54it/s]
# YOLO датасет создан в yolo_cell_dataset
# Train: 800 images, Val: 200 images

# %%
yaml_content = f"""
path: {os.path.abspath(YOLO_DATASET_DIR)}
train: train/images
val: val/images
nc: 1
names: ['cell']
"""

yaml_path = "cell_dataset.yaml"
with open(yaml_path, 'w') as f:
    f.write(yaml_content)

model = YOLO('yolov8n.pt')

results = model.train(
    data=yaml_path,
    epochs=EPOCHS,
    imgsz=416,
    batch=BATCH_SIZE,
    lr0=LR,
    device='cuda' if torch.cuda.is_available() else 'cpu',
    verbose=True,
    patience=10
)
# Out:
# Ultralytics 8.4.51  Python-3.11.9 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Ti, 16311MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=cell_dataset.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=416, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train-4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=E:\2D\runs\detect\train-4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 15.212.9 MB/s, size: 97.7 KB)
# train: Scanning E:\2D\yolo_cell_dataset\train\labels.cache... 800 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 800/800  0.0s
# val: Fast image access  (ping: 0.00.0 ms, read: 5.33.5 MB/s, size: 81.3 KB)
# val: Scanning E:\2D\yolo_cell_dataset\val\labels.cache... 200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200  0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Plotting labels to E:\2D\runs\detect\train-4\labels.jpg...
# Image sizes 416 train, 416 val
# Using 8 dataloader workers
# Logging results to E:\2D\runs\detect\train-4
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50     0.936G     0.5645      1.329     0.8242        126        416: 100% ━━━━━━━━━━━━ 50/50 10.6it/s 4.7s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 7.9it/s 0.9s0.2s
#                    all        200       1061          1      0.627      0.965      0.876
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      1.11G     0.4174     0.4965     0.8002        101        416: 100% ━━━━━━━━━━━━ 50/50 14.4it/s 3.5s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 8.5it/s 0.8s0.2s
#                    all        200       1061      0.994      0.992      0.995       0.96
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      1.11G     0.4083     0.4395     0.8013        115        416: 100% ━━━━━━━━━━━━ 50/50 14.8it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 8.2it/s 0.9s0.2s
#                    all        200       1061      0.995      0.994      0.995      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      1.11G     0.3744     0.4077     0.7978        106        416: 100% ━━━━━━━━━━━━ 50/50 14.6it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 8.6it/s 0.8s0.1s
#                    all        200       1061          1      0.997      0.995      0.974
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      1.11G     0.3386     0.3749     0.7943        120        416: 100% ━━━━━━━━━━━━ 50/50 14.8it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 8.5it/s 0.8s0.1s
#                    all        200       1061          1      0.996      0.995      0.967
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      1.11G     0.3408     0.3494     0.7962        145        416: 100% ━━━━━━━━━━━━ 50/50 14.7it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 8.5it/s 0.8s0.1s
#                    all        200       1061      0.995      0.996      0.995      0.982
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      1.11G     0.3146     0.3307     0.7926        154        416: 100% ━━━━━━━━━━━━ 50/50 14.6it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 8.8it/s 0.8s0.1s
#                    all        200       1061          1      0.998      0.995      0.979
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      1.11G     0.3208     0.3249     0.7914        121        416: 100% ━━━━━━━━━━━━ 50/50 15.0it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 8.7it/s 0.8s0.1s
#                    all        200       1061      0.998      0.999      0.995      0.984
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      1.11G      0.297     0.3026     0.7875         76        416: 100% ━━━━━━━━━━━━ 50/50 15.2it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.2it/s 0.8s0.1s
#                    all        200       1061      0.998      0.999      0.995      0.989
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      1.11G     0.3066     0.2901     0.7871        107        416: 100% ━━━━━━━━━━━━ 50/50 14.9it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.0it/s 0.8s0.1s
#                    all        200       1061          1      0.998      0.995      0.988
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      1.11G     0.2844     0.2711     0.7887        125        416: 100% ━━━━━━━━━━━━ 50/50 15.0it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 8.9it/s 0.8s0.1s
#                    all        200       1061      0.999      0.998      0.995      0.986
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      1.11G     0.2856     0.2648     0.7837        117        416: 100% ━━━━━━━━━━━━ 50/50 14.9it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.3it/s 0.8s0.1s
#                    all        200       1061          1      0.999      0.995      0.989
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      1.11G     0.2731     0.2567     0.7849        122        416: 100% ━━━━━━━━━━━━ 50/50 14.6it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 8.8it/s 0.8s0.1s
#                    all        200       1061      0.999      0.999      0.995      0.986
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      1.11G     0.2601     0.2482     0.7831        114        416: 100% ━━━━━━━━━━━━ 50/50 14.7it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.2it/s 0.8s0.1s
#                    all        200       1061          1      0.998      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      1.11G     0.2559     0.2386     0.7826        142        416: 100% ━━━━━━━━━━━━ 50/50 14.7it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.2it/s 0.8s0.1s
#                    all        200       1061          1      0.999      0.995      0.991
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      1.11G     0.2662     0.2441     0.7846        121        416: 100% ━━━━━━━━━━━━ 50/50 14.9it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.4it/s 0.7s0.1s
#                    all        200       1061          1      0.998      0.995       0.99
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      1.11G     0.2597     0.2355     0.7835        142        416: 100% ━━━━━━━━━━━━ 50/50 14.8it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.0it/s 0.8s0.1s
#                    all        200       1061          1          1      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      1.11G     0.2626     0.2342     0.7833        118        416: 100% ━━━━━━━━━━━━ 50/50 14.8it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.2it/s 0.8s0.1s
#                    all        200       1061      0.999          1      0.995      0.991
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      1.11G     0.2447     0.2298     0.7821        125        416: 100% ━━━━━━━━━━━━ 50/50 14.8it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.5it/s 0.7s0.1s
#                    all        200       1061          1      0.998      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      1.11G     0.2461     0.2262     0.7817        153        416: 100% ━━━━━━━━━━━━ 50/50 14.7it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.5it/s 0.7s0.1s
#                    all        200       1061          1      0.999      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      1.11G     0.2415     0.2228      0.785        100        416: 100% ━━━━━━━━━━━━ 50/50 14.7it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.5it/s 0.7s0.1s
#                    all        200       1061          1      0.999      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      1.11G     0.2338     0.2166      0.781         98        416: 100% ━━━━━━━━━━━━ 50/50 15.1it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.4it/s 0.7s0.1s
#                    all        200       1061      0.998          1      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      1.11G     0.2355     0.2083     0.7794        101        416: 100% ━━━━━━━━━━━━ 50/50 14.8it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.3it/s 0.8s0.1s
#                    all        200       1061      0.999          1      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      1.11G     0.2248     0.2059     0.7805        102        416: 100% ━━━━━━━━━━━━ 50/50 14.7it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.6it/s 0.7s0.1s
#                    all        200       1061      0.999          1      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      1.11G     0.2236     0.2084      0.778        135        416: 100% ━━━━━━━━━━━━ 50/50 15.0it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.3it/s 0.8s0.1s
#                    all        200       1061          1      0.999      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      1.11G     0.2189      0.203     0.7805        102        416: 100% ━━━━━━━━━━━━ 50/50 14.8it/s 3.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.3it/s 0.8s0.1s
#                    all        200       1061          1      0.999      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      1.11G     0.2189     0.2008      0.784        104        416: 100% ━━━━━━━━━━━━ 50/50 14.4it/s 3.5s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.4it/s 0.7s0.1s
#                    all        200       1061      0.999          1      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      1.11G     0.2207     0.2029     0.7789        104        416: 100% ━━━━━━━━━━━━ 50/50 14.7it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.3it/s 0.8s0.1s
#                    all        200       1061          1      0.998      0.995      0.992
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      1.11G     0.2102     0.1956     0.7777        114        416: 100% ━━━━━━━━━━━━ 50/50 14.7it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.6it/s 0.7s0.1s
#                    all        200       1061          1      0.999      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      1.11G     0.2151     0.1899     0.7803        158        416: 100% ━━━━━━━━━━━━ 50/50 14.7it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.6it/s 0.7s0.1s
#                    all        200       1061      0.999          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      1.11G      0.212     0.1865     0.7785        100        416: 100% ━━━━━━━━━━━━ 50/50 15.0it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.5it/s 0.7s0.1s
#                    all        200       1061          1      0.999      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      1.11G     0.2161     0.1882     0.7789        101        416: 100% ━━━━━━━━━━━━ 50/50 14.8it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.7it/s 0.7s0.1s
#                    all        200       1061      0.999          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      1.11G     0.2097      0.185     0.7778         57        416: 100% ━━━━━━━━━━━━ 50/50 14.7it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.5it/s 0.7s0.1s
#                    all        200       1061          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      1.11G     0.2068     0.1801     0.7774        112        416: 100% ━━━━━━━━━━━━ 50/50 14.8it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.7it/s 0.7s0.1s
#                    all        200       1061          1          1      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      1.11G     0.2004     0.1788     0.7771        119        416: 100% ━━━━━━━━━━━━ 50/50 15.1it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.9it/s 0.7s0.1s
#                    all        200       1061      0.999          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      1.11G     0.2005     0.1767      0.773         81        416: 100% ━━━━━━━━━━━━ 50/50 14.9it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.6it/s 0.7s0.1s
#                    all        200       1061          1      0.999      0.995      0.993
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      1.11G     0.1986     0.1767     0.7779        121        416: 100% ━━━━━━━━━━━━ 50/50 14.8it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.4it/s 0.7s0.1s
#                    all        200       1061          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      1.11G     0.1987     0.1747     0.7757        105        416: 100% ━━━━━━━━━━━━ 50/50 14.7it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.4it/s 0.7s0.1s
#                    all        200       1061          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      1.11G      0.194     0.1686     0.7791        103        416: 100% ━━━━━━━━━━━━ 50/50 15.0it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.8it/s 0.7s0.1s
#                    all        200       1061          1      0.999      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      1.11G     0.1955     0.1699     0.7747        107        416: 100% ━━━━━━━━━━━━ 50/50 15.0it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.3it/s 0.7s0.1s
#                    all        200       1061          1          1      0.995      0.994
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      1.11G     0.1708     0.1592     0.7684         87        416: 100% ━━━━━━━━━━━━ 50/50 14.5it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.1it/s 0.8s0.1s
#                    all        200       1061          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      1.11G     0.1764     0.1616     0.7733         73        416: 100% ━━━━━━━━━━━━ 50/50 15.1it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.3it/s 0.7s0.1s
#                    all        200       1061          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      1.11G     0.1664     0.1567       0.77         78        416: 100% ━━━━━━━━━━━━ 50/50 15.3it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.3it/s 0.8s0.1s
#                    all        200       1061          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      1.11G     0.1665     0.1583     0.7717         62        416: 100% ━━━━━━━━━━━━ 50/50 15.0it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.8it/s 0.7s0.1s
#                    all        200       1061          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      1.11G     0.1689     0.1567     0.7749         65        416: 100% ━━━━━━━━━━━━ 50/50 14.9it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.1it/s 0.8s0.1s
#                    all        200       1061          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      1.11G     0.1605     0.1498     0.7713         79        416: 100% ━━━━━━━━━━━━ 50/50 15.2it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.3it/s 0.8s0.1s
#                    all        200       1061          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      1.11G     0.1551     0.1467     0.7726         73        416: 100% ━━━━━━━━━━━━ 50/50 15.3it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.3it/s 0.8s0.1s
#                    all        200       1061          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      1.11G      0.156      0.145     0.7696         68        416: 100% ━━━━━━━━━━━━ 50/50 15.0it/s 3.3s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.5it/s 0.7s0.1s
#                    all        200       1061          1          1      0.995      0.994
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      1.11G     0.1543     0.1442     0.7706         85        416: 100% ━━━━━━━━━━━━ 50/50 14.9it/s 3.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 9.5it/s 0.7s0.1s
#                    all        200       1061          1          1      0.995      0.994
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 39, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 49 epochs completed in 0.066 hours.
# Optimizer stripped from E:\2D\runs\detect\train-4\weights\last.pt, 6.2MB
# Optimizer stripped from E:\2D\runs\detect\train-4\weights\best.pt, 6.2MB
#
# Validating E:\2D\runs\detect\train-4\weights\best.pt...
# Ultralytics 8.4.51  Python-3.11.9 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 5060 Ti, 16311MiB)
# Model summary (fused): 73 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 4.9it/s 1.4s0.2s
#                    all        200       1061          1      0.999      0.995      0.994
# Speed: 1.4ms preprocess, 0.9ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to E:\2D\runs\detect\train-4

# %%
def count_cells_from_image(model, image_tensor, confidence_threshold=0.5):
    img_disp = image_tensor.clone()
    img_disp = img_disp * torch.tensor([0.229, 0.224, 0.225]).view(3,1,1) + torch.tensor([0.485, 0.456, 0.406]).view(3,1,1)
    img_disp = (img_disp.permute(1,2,0).numpy() * 255).astype(np.uint8)
    
    results = model(img_disp, imgsz=416, conf=confidence_threshold)
    detections = results[0].boxes
    if detections is None:
        return 0
    return len(detections)

def relative_error(pred, true):
    return abs(pred - true) / max(true, 1e-6) * 100

model = YOLO('runs/detect/train/weights/best.pt')

test_dataset = val_dataset
predictions = []
ground_truths = []

for i in range(min(100, len(test_dataset))):
    img_tensor, _, true_count = test_dataset[i]
    pred_count = count_cells_from_image(model, img_tensor)
    predictions.append(pred_count)
    ground_truths.append(true_count)
    
    err = relative_error(pred_count, true_count)
    status = "OK" if err < 10 else "FAIL"
    print(f"Image {i+1:3d}: True={true_count:2d}, Pred={pred_count:2d}, Err={err:5.1f}% {status}")

errors = [relative_error(p, t) for p, t in zip(predictions, ground_truths)]
accuracy_within_10_percent = sum(e < 10 for e in errors) / len(errors) * 100

print("\n" + "="*50)
print(f"Средняя относительная погрешность: {np.mean(errors):.2f}%")
print(f"Точность (погрешность <10%): {accuracy_within_10_percent:.2f}%")
print("="*50)
# Out:
# 0: 416x416 6 cells, 10.5ms
# Speed: 2.2ms preprocess, 10.5ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 416)
# Image   1: True= 6, Pred= 6, Err=  0.0% OK
#
# 0: 416x416 6 cells, 9.2ms
# Speed: 1.5ms preprocess, 9.2ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image   2: True= 6, Pred= 6, Err=  0.0% OK
#
# 0: 416x416 1 cell, 6.8ms
# Speed: 1.6ms preprocess, 6.8ms inference, 4.4ms postprocess per image at shape (1, 3, 416, 416)
# Image   3: True= 1, Pred= 1, Err=  0.0% OK
#
# 0: 416x416 2 cells, 10.1ms
# Speed: 1.3ms preprocess, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 416)
# Image   4: True= 2, Pred= 2, Err=  0.0% OK
#
# 0: 416x416 7 cells, 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image   5: True= 7, Pred= 7, Err=  0.0% OK
#
# 0: 416x416 1 cell, 9.8ms
# Speed: 1.5ms preprocess, 9.8ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 416)
# Image   6: True= 1, Pred= 1, Err=  0.0% OK
#
# 0: 416x416 8 cells, 7.7ms
# Speed: 1.1ms preprocess, 7.7ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 416)
# Image   7: True= 8, Pred= 8, Err=  0.0% OK
#
# 0: 416x416 6 cells, 6.9ms
# Speed: 1.3ms preprocess, 6.9ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image   8: True= 6, Pred= 6, Err=  0.0% OK
#
# 0: 416x416 4 cells, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image   9: True= 4, Pred= 4, Err=  0.0% OK
#
# 0: 416x416 4 cells, 5.8ms
# Speed: 1.2ms preprocess, 5.8ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
# Image  10: True= 4, Pred= 4, Err=  0.0% OK
#
# 0: 416x416 9 cells, 9.7ms
# Speed: 1.4ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 416)
# Image  11: True= 9, Pred= 9, Err=  0.0% OK
#
# 0: 416x416 5 cells, 6.8ms
# Speed: 1.1ms preprocess, 6.8ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 416)
# Image  12: True= 5, Pred= 5, Err=  0.0% OK
#
# 0: 416x416 6 cells, 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
# Image  13: True= 6, Pred= 6, Err=  0.0% OK
#
# 0: 416x416 6 cells, 6.1ms
# Speed: 0.9ms preprocess, 6.1ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
# Image  14: True= 6, Pred= 6, Err=  0.0% OK
#
# 0: 416x416 8 cells, 7.3ms
# Speed: 1.2ms preprocess, 7.3ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 416)
# Image  15: True= 8, Pred= 8, Err=  0.0% OK
#
# 0: 416x416 9 cells, 7.2ms
# Speed: 1.3ms preprocess, 7.2ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image  16: True= 9, Pred= 9, Err=  0.0% OK
#
# 0: 416x416 3 cells, 5.5ms
# Speed: 1.0ms preprocess, 5.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  17: True= 3, Pred= 3, Err=  0.0% OK
#
# 0: 416x416 1 cell, 6.0ms
# Speed: 1.1ms preprocess, 6.0ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  18: True= 1, Pred= 1, Err=  0.0% OK
#
# 0: 416x416 7 cells, 6.9ms
# Speed: 1.2ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  19: True= 7, Pred= 7, Err=  0.0% OK
#
# 0: 416x416 2 cells, 5.6ms
# Speed: 0.9ms preprocess, 5.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  20: True= 2, Pred= 2, Err=  0.0% OK
#
# 0: 416x416 6 cells, 5.7ms
# Speed: 1.0ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  21: True= 6, Pred= 6, Err=  0.0% OK
#
# 0: 416x416 1 cell, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image  22: True= 1, Pred= 1, Err=  0.0% OK
#
# 0: 416x416 4 cells, 7.3ms
# Speed: 1.1ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
# Image  23: True= 4, Pred= 4, Err=  0.0% OK
#
# 0: 416x416 8 cells, 5.7ms
# Speed: 0.9ms preprocess, 5.7ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
# Image  24: True= 8, Pred= 8, Err=  0.0% OK
#
# 0: 416x416 1 cell, 5.8ms
# Speed: 1.1ms preprocess, 5.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  25: True= 1, Pred= 1, Err=  0.0% OK
#
# 0: 416x416 6 cells, 7.3ms
# Speed: 1.1ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
# Image  26: True= 6, Pred= 6, Err=  0.0% OK
#
# 0: 416x416 9 cells, 5.6ms
# Speed: 1.0ms preprocess, 5.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
# Image  27: True= 9, Pred= 9, Err=  0.0% OK
#
# 0: 416x416 9 cells, 6.2ms
# Speed: 1.2ms preprocess, 6.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  28: True= 9, Pred= 9, Err=  0.0% OK
#
# 0: 416x416 6 cells, 7.2ms
# Speed: 1.1ms preprocess, 7.2ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 416)
# Image  29: True= 6, Pred= 6, Err=  0.0% OK
#
# 0: 416x416 8 cells, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
# Image  30: True= 8, Pred= 8, Err=  0.0% OK
#
# 0: 416x416 7 cells, 7.0ms
# Speed: 1.1ms preprocess, 7.0ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image  31: True= 7, Pred= 7, Err=  0.0% OK
#
# 0: 416x416 7 cells, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 416)
# Image  32: True= 7, Pred= 7, Err=  0.0% OK
#
# 0: 416x416 2 cells, 5.8ms
# Speed: 1.3ms preprocess, 5.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  33: True= 2, Pred= 2, Err=  0.0% OK
#
# 0: 416x416 7 cells, 6.3ms
# Speed: 0.8ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  34: True= 7, Pred= 7, Err=  0.0% OK
#
# 0: 416x416 8 cells, 8.2ms
# Speed: 1.3ms preprocess, 8.2ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  35: True= 8, Pred= 8, Err=  0.0% OK
#
# 0: 416x416 4 cells, 10.7ms
# Speed: 1.2ms preprocess, 10.7ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 416)
# Image  36: True= 4, Pred= 4, Err=  0.0% OK
#
# 0: 416x416 9 cells, 7.2ms
# Speed: 0.9ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  37: True= 9, Pred= 9, Err=  0.0% OK
#
# 0: 416x416 9 cells, 6.5ms
# Speed: 0.9ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image  38: True= 9, Pred= 9, Err=  0.0% OK
#
# 0: 416x416 4 cells, 5.5ms
# Speed: 0.9ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  39: True= 4, Pred= 4, Err=  0.0% OK
#
# 0: 416x416 2 cells, 7.7ms
# Speed: 1.0ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image  40: True= 2, Pred= 2, Err=  0.0% OK
#
# 0: 416x416 8 cells, 6.1ms
# Speed: 0.9ms preprocess, 6.1ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
# Image  41: True= 8, Pred= 8, Err=  0.0% OK
#
# 0: 416x416 2 cells, 7.3ms
# Speed: 0.9ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  42: True= 2, Pred= 2, Err=  0.0% OK
#
# 0: 416x416 4 cells, 6.7ms
# Speed: 0.9ms preprocess, 6.7ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  43: True= 4, Pred= 4, Err=  0.0% OK
#
# 0: 416x416 5 cells, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 416)
# Image  44: True= 5, Pred= 5, Err=  0.0% OK
#
# 0: 416x416 2 cells, 6.0ms
# Speed: 0.9ms preprocess, 6.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  45: True= 2, Pred= 2, Err=  0.0% OK
#
# 0: 416x416 10 cells, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
# Image  46: True= 9, Pred=10, Err= 11.1% FAIL
#
# 0: 416x416 9 cells, 9.9ms
# Speed: 1.0ms preprocess, 9.9ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 416)
# Image  47: True= 9, Pred= 9, Err=  0.0% OK
#
# 0: 416x416 4 cells, 7.2ms
# Speed: 0.9ms preprocess, 7.2ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image  48: True= 3, Pred= 4, Err= 33.3% FAIL
#
# 0: 416x416 7 cells, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image  49: True= 7, Pred= 7, Err=  0.0% OK
#
# 0: 416x416 1 cell, 5.7ms
# Speed: 0.9ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  50: True= 1, Pred= 1, Err=  0.0% OK
#
# 0: 416x416 3 cells, 5.7ms
# Speed: 1.0ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  51: True= 3, Pred= 3, Err=  0.0% OK
#
# 0: 416x416 7 cells, 7.1ms
# Speed: 1.1ms preprocess, 7.1ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  52: True= 7, Pred= 7, Err=  0.0% OK
#
# 0: 416x416 4 cells, 5.8ms
# Speed: 0.9ms preprocess, 5.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  53: True= 4, Pred= 4, Err=  0.0% OK
#
# 0: 416x416 3 cells, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  54: True= 3, Pred= 3, Err=  0.0% OK
#
# 0: 416x416 2 cells, 6.5ms
# Speed: 0.8ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  55: True= 2, Pred= 2, Err=  0.0% OK
#
# 0: 416x416 7 cells, 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image  56: True= 7, Pred= 7, Err=  0.0% OK
#
# 0: 416x416 4 cells, 5.7ms
# Speed: 0.8ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  57: True= 4, Pred= 4, Err=  0.0% OK
#
# 0: 416x416 6 cells, 6.6ms
# Speed: 0.8ms preprocess, 6.6ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 416)
# Image  58: True= 6, Pred= 6, Err=  0.0% OK
#
# 0: 416x416 1 cell, 6.0ms
# Speed: 0.8ms preprocess, 6.0ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  59: True= 1, Pred= 1, Err=  0.0% OK
#
# 0: 416x416 2 cells, 7.1ms
# Speed: 1.0ms preprocess, 7.1ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  60: True= 2, Pred= 2, Err=  0.0% OK
#
# 0: 416x416 8 cells, 5.5ms
# Speed: 0.9ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  61: True= 8, Pred= 8, Err=  0.0% OK
#
# 0: 416x416 3 cells, 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 416)
# Image  62: True= 3, Pred= 3, Err=  0.0% OK
#
# 0: 416x416 9 cells, 6.0ms
# Speed: 0.8ms preprocess, 6.0ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  63: True= 9, Pred= 9, Err=  0.0% OK
#
# 0: 416x416 2 cells, 5.4ms
# Speed: 0.9ms preprocess, 5.4ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 416)
# Image  64: True= 2, Pred= 2, Err=  0.0% OK
#
# 0: 416x416 8 cells, 8.5ms
# Speed: 1.0ms preprocess, 8.5ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  65: True= 8, Pred= 8, Err=  0.0% OK
#
# 0: 416x416 7 cells, 5.5ms
# Speed: 1.0ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  66: True= 6, Pred= 7, Err= 16.7% FAIL
#
# 0: 416x416 9 cells, 7.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image  67: True= 9, Pred= 9, Err=  0.0% OK
#
# 0: 416x416 5 cells, 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  68: True= 5, Pred= 5, Err=  0.0% OK
#
# 0: 416x416 3 cells, 5.5ms
# Speed: 0.8ms preprocess, 5.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 416)
# Image  69: True= 3, Pred= 3, Err=  0.0% OK
#
# 0: 416x416 7 cells, 7.2ms
# Speed: 1.0ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  70: True= 8, Pred= 7, Err= 12.5% FAIL
#
# 0: 416x416 3 cells, 7.3ms
# Speed: 1.1ms preprocess, 7.3ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 416)
# Image  71: True= 3, Pred= 3, Err=  0.0% OK
#
# 0: 416x416 3 cells, 7.1ms
# Speed: 0.9ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  72: True= 3, Pred= 3, Err=  0.0% OK
#
# 0: 416x416 5 cells, 6.7ms
# Speed: 0.8ms preprocess, 6.7ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
# Image  73: True= 5, Pred= 5, Err=  0.0% OK
#
# 0: 416x416 5 cells, 5.7ms
# Speed: 0.8ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  74: True= 5, Pred= 5, Err=  0.0% OK
#
# 0: 416x416 7 cells, 5.7ms
# Speed: 0.8ms preprocess, 5.7ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  75: True= 7, Pred= 7, Err=  0.0% OK
#
# 0: 416x416 2 cells, 6.2ms
# Speed: 0.8ms preprocess, 6.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  76: True= 2, Pred= 2, Err=  0.0% OK
#
# 0: 416x416 2 cells, 10.6ms
# Speed: 1.0ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image  77: True= 2, Pred= 2, Err=  0.0% OK
#
# 0: 416x416 9 cells, 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image  78: True= 9, Pred= 9, Err=  0.0% OK
#
# 0: 416x416 2 cells, 6.1ms
# Speed: 1.0ms preprocess, 6.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  79: True= 2, Pred= 2, Err=  0.0% OK
#
# 0: 416x416 1 cell, 8.4ms
# Speed: 1.1ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  80: True= 1, Pred= 1, Err=  0.0% OK
#
# 0: 416x416 7 cells, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  81: True= 7, Pred= 7, Err=  0.0% OK
#
# 0: 416x416 5 cells, 7.5ms
# Speed: 1.0ms preprocess, 7.5ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Image  82: True= 5, Pred= 5, Err=  0.0% OK
#
# 0: 416x416 2 cells, 5.7ms
# Speed: 1.0ms preprocess, 5.7ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  83: True= 2, Pred= 2, Err=  0.0% OK
#
# 0: 416x416 9 cells, 8.7ms
# Speed: 1.0ms preprocess, 8.7ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  84: True= 9, Pred= 9, Err=  0.0% OK
#
# 0: 416x416 1 cell, 5.5ms
# Speed: 0.8ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 416)
# Image  85: True= 1, Pred= 1, Err=  0.0% OK
#
# 0: 416x416 5 cells, 6.4ms
# Speed: 0.8ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
# Image  86: True= 5, Pred= 5, Err=  0.0% OK
#
# 0: 416x416 6 cells, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  87: True= 7, Pred= 6, Err= 14.3% FAIL
#
# 0: 416x416 6 cells, 8.3ms
# Speed: 1.0ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 416)
# Image  88: True= 7, Pred= 6, Err= 14.3% FAIL
#
# 0: 416x416 2 cells, 6.4ms
# Speed: 1.1ms preprocess, 6.4ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  89: True= 2, Pred= 2, Err=  0.0% OK
#
# 0: 416x416 8 cells, 9.1ms
# Speed: 1.0ms preprocess, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 416)
# Image  90: True= 8, Pred= 8, Err=  0.0% OK
#
# 0: 416x416 4 cells, 6.4ms
# Speed: 1.0ms preprocess, 6.4ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  91: True= 4, Pred= 4, Err=  0.0% OK
#
# 0: 416x416 6 cells, 5.5ms
# Speed: 0.9ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  92: True= 6, Pred= 6, Err=  0.0% OK
#
# 0: 416x416 9 cells, 5.7ms
# Speed: 0.8ms preprocess, 5.7ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  93: True= 9, Pred= 9, Err=  0.0% OK
#
# 0: 416x416 9 cells, 6.8ms
# Speed: 0.8ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
# Image  94: True= 9, Pred= 9, Err=  0.0% OK
#
# 0: 416x416 1 cell, 7.3ms
# Speed: 1.2ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  95: True= 1, Pred= 1, Err=  0.0% OK
#
# 0: 416x416 8 cells, 7.2ms
# Speed: 1.2ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
# Image  96: True= 9, Pred= 8, Err= 11.1% FAIL
#
# 0: 416x416 6 cells, 5.4ms
# Speed: 0.9ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  97: True= 6, Pred= 6, Err=  0.0% OK
#
# 0: 416x416 1 cell, 5.5ms
# Speed: 0.8ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
# Image  98: True= 1, Pred= 1, Err=  0.0% OK
#
# 0: 416x416 6 cells, 5.8ms
# Speed: 1.0ms preprocess, 5.8ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
# Image  99: True= 6, Pred= 6, Err=  0.0% OK
#
# 0: 416x416 4 cells, 9.3ms
# Speed: 0.9ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 416)
# Image 100: True= 4, Pred= 4, Err=  0.0% OK
#
# ==================================================
# Средняя относительная погрешность: 1.13%
# Точность (погрешность <10%): 93.00%
# ==================================================

# %%
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
for i in range(10):
    row, col = i//5, i%5
    img_tensor, _, true_count = test_dataset[i]
    pred_count = count_cells_from_image(model, img_tensor)
    
    img_disp = img_tensor.clone()
    img_disp = img_disp * torch.tensor([0.229, 0.224, 0.225]).view(3,1,1) + torch.tensor([0.485, 0.456, 0.406]).view(3,1,1)
    img_disp = (img_disp.permute(1,2,0).numpy() * 255).astype(np.uint8)
    
    results = model(img_disp, imgsz=416, conf=0.5)
    annotated = results[0].plot()
    
    axes[row, col].imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
    err = relative_error(pred_count, true_count)
    color = 'green' if err < 10 else 'red'
    axes[row, col].set_title(f"#{i+1} | True: {true_count} | Pred: {pred_count}\nErr={err:.1f}%", color=color)
    axes[row, col].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 0: 416x416 9 cells, 9.3ms
# Speed: 4.6ms preprocess, 9.3ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 9 cells, 9.2ms
# Speed: 1.5ms preprocess, 9.2ms inference, 5.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 8 cells, 16.5ms
# Speed: 3.9ms preprocess, 16.5ms inference, 9.8ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 8 cells, 24.0ms
# Speed: 1.6ms preprocess, 24.0ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 4 cells, 8.0ms
# Speed: 0.9ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 4 cells, 7.3ms
# Speed: 0.8ms preprocess, 7.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 5 cells, 9.0ms
# Speed: 0.9ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 5 cells, 9.3ms
# Speed: 0.7ms preprocess, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 9 cells, 6.2ms
# Speed: 0.8ms preprocess, 6.2ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 9 cells, 7.1ms
# Speed: 0.8ms preprocess, 7.1ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 7 cells, 7.1ms
# Speed: 0.9ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 7 cells, 7.7ms
# Speed: 0.9ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 9 cells, 6.6ms
# Speed: 0.8ms preprocess, 6.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 9 cells, 7.7ms
# Speed: 0.9ms preprocess, 7.7ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 4 cells, 5.8ms
# Speed: 0.9ms preprocess, 5.8ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 4 cells, 5.8ms
# Speed: 1.0ms preprocess, 5.8ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 8 cells, 7.3ms
# Speed: 1.0ms preprocess, 7.3ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 8 cells, 5.9ms
# Speed: 1.1ms preprocess, 5.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 5 cells, 6.1ms
# Speed: 0.7ms preprocess, 6.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 5 cells, 5.8ms
# Speed: 0.8ms preprocess, 5.8ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 416)

# %%
sample_idx = 5
img_tensor, bboxes, true_count = test_dataset[sample_idx]
pred_count = count_cells_from_image(model, img_tensor)

img_disp = img_tensor.clone()
img_disp = img_disp * torch.tensor([0.229, 0.224, 0.225]).view(3,1,1) + torch.tensor([0.485, 0.456, 0.406]).view(3,1,1)
img_disp = (img_disp.permute(1,2,0).numpy() * 255).astype(np.uint8)

results = model(img_disp, imgsz=416, conf=0.5)
annotated = results[0].plot()

plt.figure(figsize=(10,10))
plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
plt.title(f"Ground truth cells: {true_count}, Detected: {pred_count}")
plt.axis('off')
plt.show()

print(f"Относительная погрешность: {relative_error(pred_count, true_count):.2f}%")
# Out:
# 0: 416x416 4 cells, 8.8ms
# Speed: 1.1ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
#
# 0: 416x416 4 cells, 8.8ms
# Speed: 0.9ms preprocess, 8.8ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 416)
# Относительная погрешность: 0.00%
